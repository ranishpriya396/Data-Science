# %% [markdown]
# 1. t = pd.Timestamp('2025/4/6')
# 2. np.array(['2015-04-07'],dtype =np.datetime64)
# 3. pd.DatetimeIndex(['2023/1/1','2024/1/1','2025/1/1']) >> use to set index
# 4. import datetime as dt >> for >> dt.datatime('2023/2/2')
# 5. pd.DatetimeIndex([dt.datetime(2023 ,1 ,1), dt.datetime(2024 ,1 ,1), dt.datetime(2025 ,1 ,1)])
# 6. index = pd.DatetimeIndex([pd.Timestamp('2023 , 1 , 1'),pd.Timestamp('2024 , 1 , 1'), pd.Timestamp('2025 , 1 , 1')])
# 7. pd.Series([1,2,3], index =index)
# 8. ###  using datetime object :
# 9. x = pd.Timestamp(dt.datetime('2023 , 1 , 1 , 9 , 21 , 56'))
# 10. x.month
# 11. x.year
# 12. x.day
# 13. x.hour
# 14. x.minute
# 15. x.second
# 16.
# 17. pd.date_range(start = '2023/01/01' end = '2023/04/04', freq = 'B'/'H'/'W'/'MS'/'M'/A , period = 25)
# 18. freq = pd.DateOffset(years= 1 )
# 19. ValueError: Of the four parameters: start, end, periods, and freq, exactly three must be specified
# 20. B > For Bussiness Day (Monday to Friday)
# 21. MS -> Month Start
# 22. ME -> Month end
# 23. h -> hourly
# 24. W -> weekly
# 25. A -> year end
# 26. pd.to_datetime('series variable' ,error = 'coerce').dt_datename()
# 27. .dt.month_name()
# 28. .dt.day_name()
# 29. .dt.is_month_end
# 30. Timedelta : represent the duration , the difference between twom dates and time :
# 31. t = pd.Timedelta(days = 2 , hours = 10 , minutes = 35,seconds = 10)
# 32. google.index
# 32. google['month_name'] = google.index.month_name()
# -    google['year_name'] = google.index.year          # Property: NO parentheses
# -    google['week_days_name'] = google.index.day_name() # Corrected: day_name()
# -    google['quarter'] = google.index.quarter
# 33. google.asfreq('YE') # 6h/h/MS/ME/YE/B/QE
#
# 34. Resampling >> resampling involves changing the frequency of your time series observations
# 35. 2 types of Resampling >> 1. Downsampling 2. Upsampling
# 36. Downsampling >> where you decrease the freaquency of the samples , such from minutes to seconds
# 37. Upsampling >> where you increase the frequency of the samples , such as from days to month
# 38. why used to reduce the noise in the data .
# 39. google['Close'].resample('W').mean().reset_index() # 'W'/ME/MS/QE/YE
# 40. interploate(method = 'linear'(By Default) / 'spline' ,  order )->>this performs a linear interpolation, which looks at the values before and after the missing data and fills the gap with an evenly spaced average.
# 41. #### Quadratic curve (requires at least 3 valid data points)
# - df['Quadratic'] = df['Values'].interpolate(method='quadratic')
#
# - #### Polynomial curve (must specify the order/degree)
# - df['Polynomial'] = df['Values'].interpolate(method='polynomial', order=2)
#
# - #### Fills missing values with the nearest existing value
# - df['Nearest'] = df['Values'].interpolate(method='nearest')
# 42. Rolling Window :
# -  google['Close'].rolling(3).mean()
# 43. Shifting => the shift() function in pandas used to , well , shift the entire series up or down by the desired number of periods

# %%
import numpy as np 
import pandas as pd
import datetime as dt

# %%
t = pd.Timestamp('2025/4/6')

# %%
type(t)
# Out:
# pandas.Timestamp

# %%
pd.Timestamp('2025-4-6')
# Out:
# Timestamp('2025-04-06 00:00:00')

# %%
pd.Timestamp('2025 , 4 , 6')
# Out:
# Timestamp('2025-04-06 00:00:00')

# %%
pd.Timestamp('2023')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
# pd.Timestamp('3rd January 2023','4th January 2023')  # error throw

# %%
import numpy as np
np.array(['2015-04-07'],dtype =np.datetime64)
# Out:
# array(['2015-04-07'], dtype='datetime64[D]')

# %%
pd.DatetimeIndex(['2023/1/1','2024/1/1','2025/1/1'])
# Out:
# DatetimeIndex(['2023-01-01', '2024-01-01', '2025-01-01'], dtype='datetime64[us]', freq=None)

# %%
pd.DatetimeIndex([pd.Timestamp('2023 , 1 , 1'),pd.Timestamp('2024 , 1 , 1'), pd.Timestamp('2025 , 1 , 1')])
# Out:
# DatetimeIndex(['2023-01-01', '2024-01-01', '2025-01-01'], dtype='datetime64[us]', freq=None)

# %%
idx = pd.DatetimeIndex([dt.datetime(2023 ,1 ,1), dt.datetime(2024 ,1 ,1), dt.datetime(2025 ,1 ,1)])

# %%
# using dataetime as series :
pd.Series([1,2,3], index =idx)
# Out:
# 2023-01-01    1
# 2024-01-01    2
# 2025-01-01    3
# dtype: int64

# %%
# using Datetime object:
x = pd.Timestamp(dt.datetime(2023 , 1 , 1 , 9 , 12 , 21 , 56))

# %%
x.month
# Out:
# 1

# %%
x.year
# Out:
# 2023

# %%
x.day
# Out:
# 1

# %%
x.hour
# Out:
# 9

# %%
x.minute
# Out:
# 12

# %%
x.second
# Out:
# 21

# %%
pd.date_range(start = '1/12/2026', end = '2/6/2026',freq = 'MS')
# Out:
# DatetimeIndex(['2026-02-01'], dtype='datetime64[us]', freq='MS')

# %%
pd.date_range(start = '1/11/2026',freq = 'MS',periods = 34)
# Out:
# DatetimeIndex(['2026-02-01', '2026-03-01', '2026-04-01', '2026-05-01',
#                '2026-06-01', '2026-07-01', '2026-08-01', '2026-09-01',
#                '2026-10-01', '2026-11-01', '2026-12-01', '2027-01-01',
#                '2027-02-01', '2027-03-01', '2027-04-01', '2027-05-01',
#                '2027-06-01', '2027-07-01', '2027-08-01', '2027-09-01',
#                '2027-10-01', '2027-11-01', '2027-12-01', '2028-01-01',
#                '2028-02-01', '2028-03-01', '2028-04-01', '2028-05-01',
#                '2028-06-01', '2028-07-01', '2028-08-01', '2028-09-01',
#                '2028-10-01', '2028-11-01'],
#               dtype='datetime64[us]', freq='MS')

# %%
df = pd.read_csv(r"C:\Users\HOME\Downloads\expense_data.csv")

# %%
df.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
# plot a graph between 'INR' AND 'DATE_MONTH'

# %%
df['Days_name'] = pd.to_datetime(df.Date).dt.day_name()
df.groupby(df['Days_name'])['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Days_name'>

# %%
df['Date_Month'] = pd.to_datetime(df.Date).dt.month_name()

# %%
df.columns
# Out:
# Index(['Date', 'Account', 'Category', 'Subcategory', 'Note', 'INR',
#        'Income/Expense', 'Note.1', 'Amount', 'Currency', 'Account.1',
#        'Days_name', 'Date_Month'],
#       dtype='str')

# %%
df.groupby(df['Date_Month'])['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date_Month'>

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df[df['Date'].dt.is_month_end].shape
# Out:
# (8, 13)

# %%
df1 = pd.read_csv(r"C:\Users\HOME\Downloads\deliveries (1).csv")

# %%
df2 = pd.read_csv(r"C:\Users\HOME\Downloads\login.csv")

# %%
google = pd.read_csv(r"C:\Users\HOME\Downloads\google (9).csv")

# %%
t1 = pd.Timestamp('6 - 1 - 2016')

# %%
t2 = pd.Timestamp('7 - 1 - 2017')

# %%
t1-t2
# Out:
# Timedelta('-395 days +00:00:00')

# %%
t2-t1
# Out:
# Timedelta('395 days 00:00:00')

# %%
#  stand alone creation :
t = pd.Timedelta(days = 2 , hours = 10 , minutes = 35,seconds = 10)

# %%
t
# Out:
# Timedelta('2 days 10:35:10')

# %%
df1.head(3)
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92

# %%
df1['order_date'] = pd.to_datetime(df1['order_date'])
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_14496\2973792906.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['order_date'] = pd.to_datetime(df1['order_date'])

# %%
df1['delivery_date'] = pd.to_datetime(df1['delivery_date'])
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_14496\4224912446.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['delivery_date'] = pd.to_datetime(df1['delivery_date'])

# %%
df1
# Out:
#     order_date delivery_date
# 0   1998-05-24    1999-02-05
# 1   1992-04-22    1998-03-06
# 2   1991-02-10    1992-08-26
# 3   1992-07-21    1997-11-20
# 4   1993-09-02    1998-06-10
# ..         ...           ...
# 496 1991-06-24    1996-02-02
# 497 1991-09-09    1998-03-30
# 498 1990-11-16    1998-04-27
# 499 1993-06-03    1993-06-13
# 500 1990-01-04    1991-10-03
#
# [501 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[us]
#  1   delivery_date  501 non-null    datetime64[us]
# dtypes: datetime64[us](2)
# memory usage: 8.0 KB

# %%
# find average delivery time 
df1['time_taken_to_order_deliver'] = df1.delivery_date - df1.order_date

# %%
df1['time_taken_to_order_deliver'].mean()
# Out:
# Timedelta('1217 days 22:53:53.532934')

# %%
google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
### Create a month name , year name , day name

# %%
google['Date'] = pd.to_datetime(google['Date'])

# %%
google.set_index('Date',inplace = True)

# %%
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20'],
#               dtype='datetime64[us]', name='Date', length=4471, freq=None)

# %%
google.asfreq('YE') # 6h/h/MS/ME/YE/B/QE
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-12-31          NaN          NaN          NaN          NaN          NaN
# 2006-12-31          NaN          NaN          NaN          NaN          NaN
# 2007-12-31   347.980682   349.933350   344.000610   344.448914   344.448914
# 2008-12-31   151.532028   154.919327   150.739990   153.250580   153.250580
# 2009-12-31   311.208527   311.532288   308.832428   308.832428   308.832428
# 2010-12-31   297.255798   298.092682   294.909607   295.875977   295.875977
# 2011-12-31          NaN          NaN          NaN          NaN          NaN
# 2012-12-31   348.693024   353.958282   346.700470   352.369232   352.369232
# 2013-12-31   554.043335   558.406982   551.064453   558.262512   558.262512
# 2014-12-31   529.795471   531.141724   524.360352   524.958740   524.958740
# ...

# %%
# Use parentheses () for .isin() and fix the start/end years
google[google.index.isin(pd.date_range(start='2022/1/6', end='2025/1/6', freq=pd.DateOffset(years=1)))]
# Out:
#                    Open         High         Low       Close   Adj Close  \
# Date
# 2022-01-06  2749.949951  2793.719971  2735.27002  2751.02002  2751.02002
#
#              Volume month_name  year_name week_days_name  quarter
# Date
# 2022-01-06  1452500    January       2022       Thursday        1

# %%
google.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#  Daily data converted into weekly mean data :
google['Close'].resample('QE').mean().reset_index()
# Out:
#          Date        Close
# 0  2004-09-30    55.211886
# 1  2004-12-31    85.182200
# 2  2005-03-31    94.299493
# 3  2005-06-30   120.979508
# 4  2005-09-30   147.513490
# ..        ...          ...
# 67 2021-06-30  2383.639203
# 68 2021-09-30  2757.403904
# 69 2021-12-31  2890.578762
# 70 2022-03-31  2719.041949
# 71 2022-06-30  2455.850286
#
# [72 rows x 2 columns]

# %%
google['Close'].resample('QE').interpolate(method = 'linear').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].resample('QE').interpolate(method = 'spline', order = 2 ).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
### Rolling Window:
google['Close'].rolling(3).mean().dropna().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
### Shifting  
google['Close'].shift(-1)
# Out:
# Date
# 2004-08-19      53.952770
# 2004-08-20      54.495735
# 2004-08-23      52.239197
# 2004-08-24      52.802086
# 2004-08-25      53.753517
#                  ...
# 2022-05-16    2334.030029
# 2022-05-17    2248.020020
# 2022-05-18    2214.909912
# 2022-05-19    2186.260010
# 2022-05-20            NaN
# Name: Close, Length: 4471, dtype: float64

# %%
google['Close'].shift(1)
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20      49.982655
# 2004-08-23      53.952770
# 2004-08-24      54.495735
# 2004-08-25      52.239197
#                  ...
# 2022-05-16    2330.310059
# 2022-05-17    2295.850098
# 2022-05-18    2334.030029
# 2022-05-19    2248.020020
# 2022-05-20    2214.909912
# Name: Close, Length: 4471, dtype: float64
